# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('tsunami_dataset.csv')
df.head()
# Out:
#     ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 0   12  -330    NaN   NaN   NaN     NaN     40.00     25.000
# 1  481  1764    2.0  11.0   NaN     NaN     51.45     -2.583
# 2   71   859    NaN   NaN   NaN     NaN     36.08     36.250
# 3  186  1580    1.0   NaN   NaN     NaN     40.00    128.000
# 4    5 -1300    NaN   NaN   NaN     NaN     39.96     26.240
#
#                          LOCATION_NAME      COUNTRY  ...       CAUSE  \
# 0  E. SPORADES ISLANDS, AEGEAN ISLANDS       GREECE  ...  Earthquake
# 1                     BRISTOL, ENGLAND           UK  ...     Unknown
# 2                            SAMANDAGI       TURKEY  ...  Earthquake
# 3                           YELLOW SEA  NORTH KOREA  ...     Unknown
# 4                 IONIAN COASTS, TROAD       TURKEY  ...     Unknown
#
#           EVENT_VALIDITY EQ_MAGNITUDE  EQ_DEPTH  TS_INTENSITY  \
# 0  Very Doubtful Tsunami          7.0       NaN           NaN
# ...

# %%
df2 = df.drop(['HOUSES_TOTAL_DESCRIPTION'],axis=1)
df2.head()
# Out:
#     ID  YEAR  MONTH   DAY  HOUR  MINUTE  LATITUDE  LONGITUDE  \
# 0   12  -330    NaN   NaN   NaN     NaN     40.00     25.000
# 1  481  1764    2.0  11.0   NaN     NaN     51.45     -2.583
# 2   71   859    NaN   NaN   NaN     NaN     36.08     36.250
# 3  186  1580    1.0   NaN   NaN     NaN     40.00    128.000
# 4    5 -1300    NaN   NaN   NaN     NaN     39.96     26.240
#
#                          LOCATION_NAME      COUNTRY  \
# 0  E. SPORADES ISLANDS, AEGEAN ISLANDS       GREECE
# 1                     BRISTOL, ENGLAND           UK
# 2                            SAMANDAGI       TURKEY
# 3                           YELLOW SEA  NORTH KOREA
# 4                 IONIAN COASTS, TROAD       TURKEY
#
#                                               REGION       CAUSE  \
# 0                                  Mediterranean Sea  Earthquake
# 1                           Northeast Atlantic Ocean     Unknown
# 2                                  Mediterranean Sea  Earthquake
# ...

# %%
# Out:
# array(['Earthquake', 'Unknown', 'Volcano', 'Landslide',
#        'Volcano and Landslide', 'Earthquake and Landslide',
#        'Questionable Earthquake', 'Volcano and Earthquake',
#        'Meteorological', 'Explosion', nan], dtype=object)

# %%
pd.get_dummies(df2,["COUNTRY"])
